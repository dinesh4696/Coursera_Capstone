# %% [markdown]
# # Topic: Neighborhood factors affecting Fuel Station sales in Tirupati
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Introduction

# %% [markdown]
# **Business Idea:** The idea of this project is to explore the neighborhoods of all fuel filling stations in Tirupati(City in India) using Foursquare to analyse how the presence of different neighborhoods affect the fuel sales of each fuel station. A machine learning model can be created with the help of which any future project proposals to setup a fuel station in Tirupati can have its yearly sales figures predicted based on the neighborhood it is being set up in.
#
# **Who would be interested:** The target audience are the stakeholders, the fuel station dealers and Oil companies who with the help of this model can get an estimate of the return on their investments before starting the project.

# %% [markdown]
# ## Data

# %% [markdown]
# **Data being used is:**
#
# *1.List of fuel filling stations in Tirupati with their Name, Latitude and Longitude.*

# %%
import pandas as pd

# %% [markdown]
# Importing Data to Notebook
#
# Example Data set:
# The data that'll be used from this table are -The name of the company that own the fuel station, the name of the fuel station, its unique code and the Latitude and longitude coordinates

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_acb93e73a67c42edbfc53da97a5368cc = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='GmlD90RmQg6EXmGWn9-9cRvJS4-HkaGyy9CVJakvTGyl',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_acb93e73a67c42edbfc53da97a5368cc.get_object(Bucket='battleofneighborhoods-donotdelete-pr-j1ddqwemzld3ht',Key='OMC Customer Master_edit.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#   State Office        Sales Area Company  Cust Code  \
# 0        TAPSO  Chittoor II  RSA    BPCL      22216
# 1        TAPSO      TIRUPATI RSA    BPCL      19990
# 2        TAPSO      TIRUPATI RSA    HPCL      20110
# 3        TAPSO  Chittoor II  RSA    BPCL      22186
# 4        TAPSO      TIRUPATI RSA    BPCL      30564
#
#                      Cust Name              Trading Area Name  \
# 0  GJN TRANSLINES-Gandlakothur                   Gandlakothur
# 1          SRAVANI FILLING STN                      Renigunta
# 2          HARSHINI PETRO PARK  Thukivakkam Renigunta Byepass
# 3         COCO - BANGARUPALYAM                 Bangarupalayam
# 4         Amma Filling Station                          NH565
#
#                          ADDRESS           STATE  DISTRICT CLASS OF MARKET  \
# 0                    Not Updated  Andhra Pradesh  CHITTOOR              D1
# 1                      Renigunta  Andhra Pradesh  CHITTOOR              D1
# ...

# %% [markdown]
# <br>

# %% [markdown]
# *2. Data of sales in 2019 of each fuel station in Tirupati.*

# %% [markdown]
# Importing Data to Notebook
#
# Example Data set: The data that'll be used from the table is - The name of the fuel station, its unique code and the Petrol and Diesel sales figures in (Kilolitres) for the year 2019.

# %%
body = client_acb93e73a67c42edbfc53da97a5368cc.get_object(Bucket='battleofneighborhoods-donotdelete-pr-j1ddqwemzld3ht',Key='HPCL Sale data.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#    S NO          CC                              RO NAME  RDB CODE  \
# 0   1.0  12651010.0  MS/HSD SREE DURGA PETROLEUM SERVICE   13002.0
# 1   2.0  12655110.0           MS/HSD BALAJI AUTO SERVICE   26784.0
# 2   3.0  12656310.0          MS/HSD MEDA SERVICE STATION   13013.0
# 3   4.0  12690110.0   MS/HSD JAYALAKSHMI SERVICE STATION   26786.0
# 4   5.0  12780010.0               MS/HSD J ANANTHARAMULU   26785.0
#
#      LOCATION              RSA COMMISSINONG DATE        DIST  MS APR2020  \
# 0   ANANTAPUR  Ananthapur  RSA               NaN  Ananthapur        24.0
# 1    GUNTAKAL     Guntakal RSA               NaN  Ananthapur        88.0
# 2   ANANTAPUR  Ananthapur  RSA               NaN  Ananthapur         0.0
# 3       GOOTY     Guntakal RSA               NaN  Ananthapur        29.0
# 4  URAVAKONDA     Guntakal RSA               NaN  Ananthapur        30.0
#
#    HSD   APR 2020  ...  MS      MAR 19  HSD   MAR 19  MS       CUMM CY  \
# ...
